# %% [markdown]
# # TOOLS_ELA
#
# *tools_ela.py* is a command line tool that extracts information from original transcribed text. The provided information is:
#
# 1. Indexes of Words, Lemmas, Types
# 2. Frequencies of Lemmas, Types
# 3. Concordances
# 4. TTR
# 5. Collocations (for both words and lemmas)
# 6. N-grams
# 7. Min, Max and Mean lengths of Types
# 8. POS Tagging (both Bayesian and HMM - Hidden Markov Model)
# 9. TEI attributes (on TEI files)
# 10. TEI entity lists (on TEI files)
#
# The tool can handle both *XML-TEI encoded* and pure-text files. By default it handles *XML-TEI*, but a command line argument chan instruct the tool to treat files as text. It is actually a multiplatform tool, actively tested on both Linux and Windows. It works in the current Python *virtual environment*, the same as this Jupyter Lab session.
#
# In the same directory as *tools_ela.py* a configuration file is required, namely *tools_ela.cfg*, that specifies working directories. The default configuration is
#
# ```
# [Paths]
# base = .
# origin_subdir = SOURCE/ela_txt
# result_subdir = RESULT/tools_ela
# database = tools_ela.db
# ```
#
# Apart from the database, it means that input files are expected to be in `SOURCE/ela_txt` and the results will be written in `RESULT/tools_ela`; the source directory is considered to be *flat*, thus no subdirectories are traversed. Results are stored in a flat directory as well. Result files keep their base prefix and have suffixes such as the following:
#
# * `BASEPREFIX_collocations.json`: word collocations
# * `BASEPREFIX_lemma_collocations.json`: lemma collocations (latin only)
# * `BASEPREFIX_ngrams.json`: ngrams (at various levels)
# * `BASEPREFIX_concordances.txt`: concordances (*note: these are text lines*)
# * `BASEPREFIX_statistics.json`: statistics on the latin part of text
# * `BASEPREFIX_fulltext_statistics.json`: statistics on all text for all languages
# * `BASEPREFIX_tei_attrs.json`: data from the XML-TEI header
# * `BASEPREFIX_tei_lists.json`: lists from XML-TEI encoding (*persName*, *geogName*, *placeName*)
#
# All results, except for *concordances*, are in JSON format.
#
# **Note:** *tools_ela.py* requires CLTK to be installed, and the `latin_models_cltk` corpus to be loaded. This can be performed from a Python session as follows:
#
# ```
# >>> from cltk.corpus.utils.importer import CorpusImporter
# >>> corpus_importer = CorpusImporter('latin')
# >>> corpus_importer.import_corpus('latin_models_cltk')
# ```
#
# otherwise the tool will exit with a warning. Also, in order to produce data related to *TEI lists* (namely places and people), the *tools_ela.db* has to be present, created from updated dumps of the *Pleiades* and *Geonames* databases. This can be done using the *nbk_dbload* notebook.
#
# The following are the command line parameters:

# %%
# !python tools_ela.py --help
# Out:
# usage: tools_ela.py [-h] [-a] [-C N] [-L N] [-N N] [-O] [-B] [-M] [-T] [-A]
#                     [-S] [-v] [-p] [--full-monty]
#                     [BASE_FILENAME]
#
# Preprocess latin text file(s) for ELA
#
# positional arguments:
#   BASE_FILENAME         base of filename to process (no directory/extension)
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a, --all             process all files in the source directory
#   -C N, --collocations N
#                         generate collocations file with window up to N
#                         [N=2..5]
#   -L N, --lemma-collocations N
#                         generate lemma collocations file with window up to N
#                         [N=2..5]
#   -N N, --ngrams N      generate ngrams file of sizes up to N [N=2..5]
#   -O, --concordances    generate concordances file
#   -B, --bayesian-pos    generate bayesian POS tag file
#   -M, --hmm-pos         generate HMM base POS tag file
#   -T, --assume-text     assume simple text files instead of XML-TEI
#   -A, --tei-attrs       generate XML-TEI header attributes file
#   -S, --tei-lists       generate XML-TEI lists file
#   -v, --verbose         produce verbose output and timings
#   -p, --para            include split paragraph data in statistics file
#   --full-monty          generate MOST files for specified texts

# %% [markdown]
# To invoke the tool for a specific file the `BASE_FILENAME` attribute has to be explicitly specified, *without* extension: extension will be chosen by *tools_ela.py* between *.txt* and *.xml* depending on whether `--assume-text` has been provided or not. To process all files in a directory, just specify `--all`. The `--full-monty` switch is an utility that generates most useful information (actually: everything but *POS tagging*) without having to specify all related command line switches. Thus, for instance, to regenerate POS tagging for *Epistola.xml* in the source directory, issue the following:
#
# ```
# $ python tools_ela.py -v -p -M -B Epistola
# ```
#
# and to generate most useful information the following command can be launched, as we will do below:
#
# ```
# $ python tools_ela.py --full-monty --verbose -a
# ```
#
# **Note:** For optimal results this tool should be used on XML-TEI files processed by *RETAG*.
#
# The following cell invokes the *tools_ela.py* from the command line, in the above form.

# %%
# !python tools_ela.py --full-monty --verbose -a
# Out:
# [Sun Feb 23 02:52:34 2020] reading configuration from 'tools_ela.cfg'
# [Sun Feb 23 02:52:41 2020] notice: assuming input files are in XML-TEI specific format
# [Sun Feb 23 02:52:41 2020] extracting: statistics
# [Sun Feb 23 02:52:41 2020] extracting: collocations (window max size: 5)
# [Sun Feb 23 02:52:41 2020] extracting: lemma_collocations (window max size: 5)
# [Sun Feb 23 02:52:41 2020] extracting: ngrams (ngram max size: 5)
# [Sun Feb 23 02:52:41 2020] extracting: concordances
# [Sun Feb 23 02:52:41 2020] extracting: XML-TEI header attributes
# [Sun Feb 23 02:52:41 2020] extracting: XML-TEI element lists
# [Sun Feb 23 02:52:41 2020] starting process for all files
# [Sun Feb 23 02:52:41 2020] environment:
# source: 'SOURCE/ela_txt'
# destination: 'RESULT/tools_ela'
# [Sun Feb 23 02:52:41 2020] logging errors to: 'error.log'
# [Sun Feb 23 02:52:41 2020] --- BEGIN ---
# [Sun Feb 23 02:52:54 2020] processed: 'ELA_2_2_loyola_a_saverius_15491223' (elapsed: 13.432 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 02:53:05 2020] processed: 'ELA_2_0_primus_catalogus_provinciae_philippinarum_16210501' (elapsed: 10.560 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 02:53:13 2020] processed: 'ELA_2_2_nicolaus_lancillottus_siignatio_de_loyola1550' (elapsed: 8.554 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 02:53:22 2020] processed: 'ELA_2_2_majorica_indiculus_alphabeticus_1654' (elapsed: 8.290 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 02:53:53 2020] processed: 'ELA_2_2_paschalisdavictoria_epistola' (elapsed: 31.436 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 02:54:02 2020] processed: 'ELA_2_2_nunezbarreto_a_lainez_15580113' (elapsed: 8.753 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 02:54:10 2020] processed: 'ELA_2_2_p.ioannes_de_polanco_ex_comm_nicolaus_lancillottus_epistola15471122' (elapsed: 8.531 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 02:54:19 2020] processed: 'ELA_2_2_p.ioannes_de_polanco_ex_comm_nicolaus_lancillottus_epistola1547' (elapsed: 8.268 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 02
sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:03:50 2020] processed: 'ELA_2_2_ignatius_de_loyola_p_francisco_xaverio_10_oct_1549' (elapsed: 7.847 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:04:03 2020] processed: 'ELA_2_2_valignanus_epistula_de_martirio' (elapsed: 12.469 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:04:11 2020] processed: 'ELA_2_2_martyrium_fr_minorum_almaligh' (elapsed: 8.110 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:04:35 2020] processed: 'ELA_2_2_iohannesdemontecorvino_epistula2' (elapsed: 23.917 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:04:44 2020] processed: 'ELA_2_2_elenchus_patrum_jap_165409' (elapsed: 9.530 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:04:57 2020] processed: 'GUT_3_2_colladus_ars_grammaticae' (elapsed: 12.561 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:05:10 2020] processed: 'ELA_2_2_primus_catalogus_jap_1654' (elapsed: 13.259 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:05:23 2020] processed: 'ELA_2_2_catalogo_para_claudio_aqua_viva_1588' (elapsed: 12.617 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:05:31 2020] processed: 'ELA_2_0_de_ledesma_catalogus_16190220' (elapsed: 8.005 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:05:50 2020] processed: 'ELA_2_2_augustinusapaschalis_epistola_16891211' (elapsed: 19.441 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:06:28 2020] processed: 'ELA_2_2_bonaventura_ibanez_epistola_ad_episcopos_tunkinenses_1674' (elapsed: 37.988 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:06:37 2020] processed: 'ELA_2_2_nunezbarreto_a_loyola_15551127' (elapsed: 8.531 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:06:46 2020] processed: 'ELA_2_2_ludovicus_goncalves_da_camara_ignatio_de_loyola_8_apr_1550' (elapsed: 8.532 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:08:36 2020] processed: 'ELA_2_2_augustinusapaschali_epistola_16841215' (elapsed: 110.520 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:08:45 2020] processed: 'ELA_2_2_ignatius_de_loyola_f_xaverio_1550' (elapsed: 8.613 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:08:53 2020] processed: 'ELA_2_2_de_ledesma_catalogus_1615' (elapsed: 8.346 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:09:41 2020] processed: 'ALIM_3_1_odoricus_relatio' (elapsed: 47.364 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:10:19 2020] processed: 'ELA_2_2_augustinus_paschalis_responsum_1689113030' (elapsed: 38.493 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:10:28 2020] processed: 'ELA_2_2_montefusculus_acta_congregationis_1650' (elapsed: 8.644 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:10:36 2020] processed: 'ELA_2_2_majorica_tertius_catalogus_provinciae_japonicae' (elapsed: 8.678 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:11:36 2020] processed: 'ALIM_3_1_de_marignollis_relatio' (elapsed: 59.849 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:11:45 2020] processed: 'ELA_2_2_saverius_a_loyola_15480120' (elapsed: 8.563 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:11:53 2020] processed: 'ELA_2_2_saverius_a_loyola_15490114' (elapsed: 8.491 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:12:06 2020] processed: 'ELA_2_2_bonaventura_ibanez_epistola_ad_cardinales_1672' (elapsed: 13.008 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:12:15 2020] processed: 'ELA_2_2_depolanco_excerpta_e_litteris_155601' (elapsed: 8.881 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:12:24 2020] processed: 'ELA_2_2_cathalogus_domorum_1954' (elapsed: 8.648 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:13:45 2020] processed: 'ELA_2_2_martini_brevis_relatio' (elapsed: 81.098 sec, produced: stats-latin, lemma_collocations, ngrams, stats-fulltext, collocations, concordances)
# [Sun Feb 23 03:13:45 2020] --- END ---
# [Sun Feb 23 03:13:45 2020] process ended: 64 files processed, 0 skipped (1264.413 sec)

# %% [markdown]
# Now the `RESULT/tools_ela` directory contains all the requested information.
